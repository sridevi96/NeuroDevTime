# %% [markdown]
# # Age prediction in Herb et al., 2023 human fetal hypothalamus
# ## <i>Part 1. Data processing for developmental age prediction</i>
# ><b> This notebook contains R code to process Herb et al.2023, a fetal human hypothalamus dataset used in our paper for developmental age prediction.<br>Part 2 uses the pre-trained celltype agnostic model to predict developmental age from the transcriptome </b>

# %%
setwd("/home/sridevi/inkwell03_sridevi//metadevorganoid/werneranalysis/DevTime_gitub_repo/") #change to the working directory

# %%
library(Seurat)
library(dplyr)
library(caret)
library(readr)
library(ggplot2)
library(stringr)
library(ggpubr)
library(tidyr)

# %% [markdown]
# ## <i> Generate celltype aggregate transcriptomes per sample </i>
# >We will load a list of seurat objects corresponding to different samples in Herb 2023, then aggregate the expression of all cells per cell type per sample

# %%
load("data/Herb_hypothalamus_2023/Herb_hypothalamus_2023.Rdata") #LIST OF SEURAT OBJECTS CALLED HYPODAT
load("data/Herb_hypothalamus_2023/Sample_metadata.Rdata")#METADATA DOWNLOADED FROM PAPER SUPPLEMENTARY
final_common_genes<-readRDS("models/commongenes.rds")#list of common genes

# %%
#Split the Herb metadata by the sample
Herb_metadata<-Herb_hypothalamus_celltypelabels%>%filter(study=="Herb")
split_Herb_metadata<-split(Herb_metadata,f = Herb_metadata$sample)
# Out:
# $`Herb-1`
# # A tibble: 3,962 × 10
#    Barcode  CellTypes UMAP_1 UMAP_2 UMAP_3 filtered_barcode dev_age sample   age
#    <chr>    <chr>     <chr>  <chr>  <chr>  <chr>            <chr>   <chr>  <dbl>
#  1 CS13_AA… tRGC      0.759… 1.024… -1.22… AAACCTGAGAAACCAT CS13    Herb-1     6
#  2 CS13_AA… Ependymal 2.058… 3.826… 10.26… AAACCTGAGCGTAATA CS13    Herb-1     6
#  3 CS13_AA… qRGC      1.494… -0.95… 5.905… AAACCTGCAATGGACG CS13    Herb-1     6
#  4 CS13_AA… qRGC      -0.44… -1.36… 3.965… AAACCTGCAGGACCCT CS13    Herb-1     6
#  5 CS13_AA… cRGC      -3.24… -3.04… 4.650… AAACCTGCAGGGTTAG CS13    Herb-1     6
#  6 CS13_AA… qRGC      1.178… -1.11… 4.631… AAACCTGCATATACGC CS13    Herb-1     6
#  7 CS13_AA… qRGC      1.533… -0.45… 4.292… AAACCTGGTCGCTTTC CS13    Herb-1     6
#  8 CS13_AA… tRGC      -6.95… 0.068… -0.70… AAACCTGTCAAGATCC CS13    Herb-1     6
#  9 CS13_AA… cRGC      -3.54… -2.56… 3.995… AAACGGGAGTCGATAA CS13    Herb-1     6
# 10 CS13_AA… cRGC      -2.42… -2.21… 1.561… AAACGGGCACCCAGTG CS13    Herb-1     6
# # ℹ 3,952 more rows
# # ℹ 1 more variable: study <chr>
#
# $`Herb-10`
# # A tibble: 2,800 × 10
#    Barcode  CellTypes UMAP_1 UMAP_2 UMAP_3 filtered_barcode dev_age sample   age
#    <chr>    <chr>     <chr>  <chr>  <chr>  <chr>            <chr>   <chr>  <dbl>
#  1 CS14_AA… Neuronal  0.622… 2.901… 1.390… AACGTTGGTACGAAAT CS14    Herb-2     7
#  2 CS14_AA… qRGC      2.073… -0.58… 4.565… AACGTTGTCTAACTCT CS14    Herb-2     7
#  3 CS14_AA… Microglia -11.4… -0.12… -0.58… AACTCAGAGTAGATGT CS14    Herb-2     7
#  4 CS14_AA… tRGC      -4.60… 0.782… 1.953… AACTCAGCAAGCCGCT CS14    Herb-2     7
#  5 CS14_AA… cRGC      -3.14… -3.56… 5.136… AACTCAGCACAAGCCC CS14    Herb-2     7
#  6 CS14_AA… cRGC      -1.29… -2.32… 2.599… AACTCTTAGGAGCGTT CS14    Herb-2     7
#  7 CS14_AA… cRGC      -1.38… -2.61… 4.875… AACTCTTGTGGCGAAT CS14    Herb-2     7
#  8 CS14_AA… tRGC      -4.82… 0.152… -0.17… AACTTTCAGATCTGCT CS14    Herb-2     7
#  9 CS14_AA… cRGC      -3.23… -3.30… 4.996… AACTTTCAGTAGCGGT CS14    Herb-2     7
# 10 CS14_AA… cRGC      -3.61… -3.93… 5.282… AACTTTCAGTGATCGG CS14    Herb-2     7
# # ℹ 594 more rows
# # ℹ 1 more variable: study <chr>
#
# $`Herb-3`
# # A tibble: 2,936 × 10
#    Barcode  CellTypes UMAP_1 UMAP_2 UMAP_3 filtered_barcode dev_age sample   age
#    <chr>    <chr>     <chr>  <chr>  <chr>  <chr>            <chr>   <chr>  <dbl>
#  1 CS15_AA… Neuronal  1.167… 3.064… -3.30… AAACCTGAGCAGCGTA CS15    Herb-3     7
#  2 CS15_AA… qRGC      0.219… -0.44… 6.300… AAACCTGCAGGGATTG CS15    Herb-3     7
#  3 CS15_AA… tRGC      -5.03… 0.857… 1.651… AAACCTGGTACGCTGC CS15    Herb-3     7
#  4 CS15_AA… cRGC      -3.50… -4.12… 4.792… AAACCTGTCACGCGGT CS15    Herb-3     7
#  5 CS15_AA… cRGC      -1.26… -2.34… 2.058… AAACGGGAGATCGATA CS15    Herb-3     7
#  6 CS15_AA… cRGC      -3.97… -1.40… 1.117… AAACGGGCAGCGTAAG CS15    Herb-3     7
#  7 CS15_AA… tRGC      -1.95… 1.375… -1.13… AAACGGGGTTTGTGTG CS15    Herb-3     7
#  8 CS15_AA… tRGC      -4.30… 1.532… 0.088… AAACGGGTCATCGCTC CS15    Herb-3     7
#  9 CS15_AA… tRGC      -3.63… 1.591… -0.22… AAACGGGTCCGTAGTA CS15    Herb-3     7
# 10 CS15_AA… cRGC      -3.65… -3.97… 5.171… AAACGGGTCGCATGAT CS15    Herb-3     7
# # ℹ 2,926 more rows
# # ℹ 1 more variable: study <chr>
#
# $`Herb-4`
# # A tibble: 1,752 × 10
#    Barcode  CellTypes UMAP_1 UMAP_2 UMAP_3 filtered_barcode dev_age sample   age
#    <chr>    <chr>     <chr>  <chr>  <chr>  <chr>            <chr>   <chr>  <dbl>
#  [6] "GW16_hypo"    "GW18_hypo"    "GW19_hypo"    "GW20_34_hypo" "GW22T_hypo1"
# [11] "GW25_3V_hypo"
#  [1] "CS13"         "GW22T_hypo1"  "GW25_3V_hypo" "CS14"         "CS15"
#  [6] "CS22_2_hypo"  "CS22_hypo"    "GW16_hypo"    "GW18_hypo"    "GW19_hypo"
# [11] "GW20_34_hypo"

# %%
#Add metadata to each Herb object and filter to keep cells with metadata assigned cell types only
Herb_filtered_data<-lapply(1:length(HypoDat),function(x){
    sample_name<-names(HypoDat)[[x]]
    data=HypoDat[[sample_name]]
    metadata=split_Herb_metadata[[sample_name]]
    filtered_data<-data[,metadata$Barcode]
    filtered_data<-AddMetaData(filtered_data,metadata = metadata[match(Cells(filtered_data),metadata$Barcode),])
    return(filtered_data)
})
# Out:
# Warning message:
# “Setting row names on a tibble is deprecated.”
# Warning message:
# “Setting row names on a tibble is deprecated.”
# Warning message:
# “Setting row names on a tibble is deprecated.”
# Warning message:
# “Setting row names on a tibble is deprecated.”
# Warning message:
# “Setting row names on a tibble is deprecated.”
# Warning message:
# “Setting row names on a tibble is deprecated.”
# Warning message:
# “Setting row names on a tibble is deprecated.”
# Warning message:
# “Setting row names on a tibble is deprecated.”
# Warning message:
# “Setting row names on a tibble is deprecated.”
# Warning message:
# “Setting row names on a tibble is deprecated.”
# Warning message:
# “Setting row names on a tibble is deprecated.”

# %%
#Aggregate expression at the celltype level
names(Herb_filtered_data)<-lapply(Herb_filtered_data,function(x){unique(x$dev_age)})
merged_Herb_filtered<-merge(Herb_filtered_data[[1]],Herb_filtered_data[-1])

Herb_pseudobulk_celltypes_rawcounts<- lapply(Herb_filtered_data,function(x){
    AggregateExpression(x,assays = "RNA",group.by = "CellTypes",return.seurat = TRUE)})
# Out:
# Names of identity class contain underscores ('_'), replacing with dashes ('-')
# This message is displayed once every 8 hours.
# Centering and scaling data matrix
#
# Centering and scaling data matrix
#
# Centering and scaling data matrix
#
# Centering and scaling data matrix
#
# Centering and scaling data matrix
#
# Centering and scaling data matrix
#
# Centering and scaling data matrix
#
# Centering and scaling data matrix
#
# Centering and scaling data matrix
#
# Centering and scaling data matrix
#
# Centering and scaling data matrix

# %%
Herb_pseudobulk_celltypes_rawcounts
# Out:
# $CS13
# An object of class Seurat
# 33694 features across 18 samples within 1 assay
# Active assay: RNA (33694 features, 0 variable features)
#  3 layers present: counts, data, scale.data
#
# $CS14
# An object of class Seurat
# 33694 features across 12 samples within 1 assay
# Active assay: RNA (33694 features, 0 variable features)
#  3 layers present: counts, data, scale.data
#
# $CS15
# An object of class Seurat
# 33694 features across 18 samples within 1 assay
# Active assay: RNA (33694 features, 0 variable features)
#  3 layers present: counts, data, scale.data
#
# $CS22_hypo
# An object of class Seurat
# 33694 features across 15 samples within 1 assay
# Active assay: RNA (33694 features, 0 variable features)
#  3 layers present: counts, data, scale.data
#
# $CS22_2_hypo
# An object of class Seurat
# 33694 features across 12 samples within 1 assay
# Active assay: RNA (33694 features, 0 variable features)
#  3 layers present: counts, data, scale.data
#
# $GW16_hypo
# An object of class Seurat
# 33694 features across 20 samples within 1 assay
# Active assay: RNA (33694 features, 0 variable features)
#  3 layers present: counts, data, scale.data
#
# $GW18_hypo
# An object of class Seurat
# 33694 features across 19 samples within 1 assay
# Active assay: RNA (33694 features, 0 variable features)
#  3 layers present: counts, data, scale.data
#
# $GW19_hypo
# An object of class Seurat
# 33694 features across 19 samples within 1 assay
# Active assay: RNA (33694 features, 0 variable features)
#  3 layers present: counts, data, scale.data
#
# $GW20_34_hypo
# An object of class Seurat
# 33694 features across 19 samples within 1 assay
# Active assay: RNA (33694 features, 0 variable features)
#  3 layers present: counts, data, scale.data
#
# $GW22T_hypo1
# An object of class Seurat
# 33694 features across 19 samples within 1 assay
# Active assay: RNA (33694 features, 0 variable features)
#  3 layers present: counts, data, scale.data
#
# $GW25_3V_hypo
# An object of class Seurat
# 33694 features across 20 samples within 1 assay
# Active assay: RNA (33694 features, 0 variable features)
#  3 layers present: counts, data, scale.data

# %%
#for 1:5, we need to add their corresponding gestation weeks from carnegie stage, so cs13=
age_carnegiestage<-c(6,7,7,10,10)#CS 13,14,15,22 respectively

# %%
#making sure list names have the age in them
names(Herb_pseudobulk_celltypes_rawcounts)[1:5]<-paste0(names(Herb_pseudobulk_celltypes_rawcounts)[1:5],"_GW",age_carnegiestage[1:5])

# %%
#Function to create a list of matrices, one for each celltype with columns corresponding to different samples
create_matrices_by_strings <- function(list_of_matrices, strings) {
  new_list <- lapply(strings, function(str) {
    lapply(list_of_matrices, function(mat) {
      selected_cols <- which(colnames(mat)==str)
      if (any(selected_cols)) {
        mat[, selected_cols, drop = FALSE]
      } else {
        matrix(NA, nrow = nrow(mat), ncol = 0)
      }
    })
  })
  new_list
}

# %%
Herb_celltypes<-unique(unlist(lapply(Herb_pseudobulk_celltypes_rawcounts,colnames)))
Herb_pb_celltypesbyage<-create_matrices_by_strings(Herb_pseudobulk_celltypes_rawcounts,Herb_celltypes)
names(Herb_pb_celltypesbyage)<-Herb_celltypes
# Out:
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”
# Warning message:
# “The following arguments are not used: drop”

# %%
#get a merged matrix of all cell type transcriptomes per sample
Herb_pb_combinedcelltypes<-lapply(Herb_pb_celltypesbyage,function(seuratobjlist){
    #each is a list of seurat objects with different times, some maybe empty
    indextoskip<-lapply(seuratobjlist,is.logical)%>%unlist()
    filteredlist<-seuratobjlist[!indextoskip]
    temp<-names(filteredlist)
    tempdata<-lapply(filteredlist,function(x){x@assays[["RNA"]]@layers[["data"]]})%>%do.call(cbind,.)
    rownames(tempdata)<-Features(Herb_pb_celltypesbyage$Astrocytes$CS13_GW6)#set rownames as genes from one sample
    return(tempdata)
    })%>%do.call(cbind,.)%>%.[final_common_genes,]#restrict to only the common genes

# %%
#get list of all cell types in the combined matrix
subtract_Herb<-lapply(Herb_pb_celltypesbyage,function(x){lapply(x,is.logical)%>%unlist%>%sum}) #some of the list elements are empty
celltypes_Herb<-list()
for (i in 1:length(Herb_pb_celltypesbyage)){
  celltypes_Herb[[i]]<-rep(names(Herb_pb_celltypesbyage)[i],11-subtract_Herb[[i]])
}
celltypes_Herb<-unlist(celltypes_Herb)

# %%
Herb_metadata<-data.frame(study=rep("Herb",ncol(Herb_pb_combinedcelltypes)),
                          obs_age=str_extract(colnames(Herb_pb_combinedcelltypes), "(?<=GW)\\d+"),
                          celltypes=celltypes_Herb)

# %%
save(Herb_pb_combinedcelltypes,Herb_metadata,file="processed_data/Herb_processed.Rdata")

# %% [markdown]
# ---

# %% [markdown]
# # <i> Part 2. Developmental age prediction using cell type agnostic model
# ><b> We will use the original cell type agnostic model stored in /models to verify predicted ages in the Herb 2023 dataset

# %%
celltypeagnosticmodel<-readRDS("models/original_celltypeagnostic_model.rds")

# %%
#check model coefficients
coefs<-as.data.frame(coef(celltypeagnosticmodel$finalModel, celltypeagnosticmodel$finalModel$lambdaOpt))%>%dplyr::filter(s1!=0)
coefs$genes<-rownames(coefs)
coefs
# Out:
#             s1          genes
# (Intercept) 11.25612595 (Intercept)
# PDK4         0.40616305 PDK4
# TAC1        -0.06138818 TAC1
# CX3CL1       2.02815101 CX3CL1
# PNPLA4      -0.96997077 PNPLA4
# CACNA2D2    -1.85735642 CACNA2D2
# CAMK1G       0.44071996 CAMK1G
# NFIX         0.15785721 NFIX
# CD9          0.06357692 CD9
# APBA3       -0.57331962 APBA3
# CEP68        0.57225408 CEP68
# EHD3         1.06858807 EHD3
# MVP          0.69098406 MVP
# RALBP1      -0.38352944 RALBP1
# AKAP11       0.01182575 AKAP11
# VIM         -0.05311728 VIM
# FAS          2.62707888 FAS
# TUBG2        1.27400215 TUBG2
# MRI1        -0.16880257 MRI1
# FAM184B      0.63791276 FAM184B
# LMO3        -0.02480414 LMO3
# KITLG        0.41441151 KITLG
# PER3         0.02690560 PER3
# FSTL4        0.36356085 FSTL4
# ANAPC4       0.03942497 ANAPC4
# CAMK2B       0.64202666 CAMK2B
# BCAT1       -1.09880574 BCAT1
# CA11         0.12709203 CA11
# LPAR2       -0.73669468 LPAR2
# GSTO2        0.09829561 GSTO2
# ⋮           ⋮           ⋮
# HCG11       -1.40099270 HCG11
# TMEM254-AS1  0.18516563 TMEM254-AS1
# MCTS1       -0.34800636 MCTS1
# SNHG7       -0.08834656 SNHG7
# ANKRD65      2.30576721 ANKRD65
# ZSCAN31      0.03152213 ZSCAN31
# ARHGDIG      0.26808520 ARHGDIG
# AP5Z1       -0.01612955 AP5Z1
# TTC4         0.89995139 TTC4
# ZNF324B     -1.04489480 ZNF324B
# HS3ST5      -0.21336131 HS3ST5
# MALAT1       0.08159199 MALAT1
# ZNF224       0.34816624 ZNF224
# EGLN2        0.50719092 EGLN2
# ZNF595       1.37807239 ZNF595
# TMEM54       0.01385577 TMEM54
# DMGDH        0.33303495 DMGDH
# CCDC74B     -0.77662145 CCDC74B
# CYB5R2      -0.05808639 CYB5R2
# ACY1        -0.15697154 ACY1
# HSPB6        0.55598072 HSPB6
# CYP2E1       0.58274305 CYP2E1
# MGARP        1.60258556 MGARP
# ZNF185      -1.25232825 ZNF185
# AMIGO2      -2.70810215 AMIGO2
# USP43        0.37605794 USP43
# IL34         0.81975253 IL34
# DYNLRB2     -0.19897073 DYNLRB2
# VMO1         2.84681860 VMO1
# ELF3        -1.95876147 ELF3

# %%
herb_predicted_ages=predict(celltypeagnosticmodel,t(Herb_pb_combinedcelltypes))
Herb_metadata$predictedage<-herb_predicted_ages
mean_age<-Herb_metadata%>%group_by(obs_age)%>%summarise(avg=mean(predictedage),
                                                              sem=(sd(predictedage)/sqrt(length(predictedage))))

# %%
ggplot(data=Herb_metadata,aes(x=as.numeric(obs_age),y=predictedage))+geom_point(alpha=0.5,aes(col=celltypes))+stat_cor()+
ggtitle("Model predictions in Herb 2023 hypothalamus data")+xlab("Actual age (gestation weeks)")+ylab("Predicted age (gestation weeks)")+
geom_abline(slope=1,linetype=3)+
geom_point(data=mean_age,aes(x=as.numeric(obs_age),y=avg),size=4,shape="square")+
geom_errorbar(data=mean_age,aes(x=as.numeric(obs_age),y=avg,ymin=avg-sem,ymax=avg+sem),width=0.2)
# Out:
# plot without title

# %% [markdown]
# Predicted ages are highly correlated to the actual age in a human fetal dataset not used for training

# %%
print(sessionInfo())
# Out:
# R version 4.3.1 (2023-06-16)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Rocky Linux 9.5 (Blue Onyx)
#
# Matrix products: default
# BLAS/LAPACK: /home/sridevi/anaconda3/envs/r_env/lib/libopenblasp-r0.3.4.so;  LAPACK version 3.8.0
#
# locale:
#  [1] LC_CTYPE=en_CA.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_CA.UTF-8        LC_COLLATE=en_CA.UTF-8
#  [5] LC_MONETARY=en_CA.UTF-8    LC_MESSAGES=en_CA.UTF-8
#  [7] LC_PAPER=en_CA.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_CA.UTF-8 LC_IDENTIFICATION=C
#
# time zone: America/Toronto
# tzcode source: system (glibc)
#
# attached base packages:
# [1] grid      stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] circlize_0.4.16       ComplexHeatmap_2.18.0 tidyr_1.3.1
#  [4] ggpubr_0.6.0          stringr_1.5.1         readr_2.1.5
#  [7] caret_6.0-94          lattice_0.22-6        ggplot2_3.5.1
# [10] dplyr_1.1.4           Seurat_5.1.0          SeuratObject_5.0.2
# [13] sp_2.1-4
#
# loaded via a namespace (and not attached):
#   [1] RcppAnnoy_0.0.22       splines_4.3.1          later_1.3.2
#   [4] pbdZMQ_0.3-13          tibble_3.2.1           polyclip_1.10-7
#   [7] hardhat_1.4.0          pROC_1.18.5            rpart_4.1.23
#  [10] fastDummies_1.7.4      lifecycle_1.0.4        rstatix_0.7.2
#  [13] doParallel_1.0.17      globals_0.16.3         MASS_7.3-60
#  [16] backports_1.5.0        magrittr_2.0.3         plotly_4.10.4
#  [19] httpuv_1.6.15          sctransform_0.4.1      spam_2.11-0
#  [22] spatstat.sparse_3.1-0  reticulate_1.39.0      cowplot_1.1.3
#  [25] pbapply_1.7-2          RColorBrewer_1.1-3     lubridate_1.9.3
#  [28] abind_1.4-8            Rtsne_0.17             purrr_1.0.2
#  [31] BiocGenerics_0.48.1    nnet_7.3-19            ipred_0.9-15
#  [34] lava_1.8.0             IRanges_2.36.0         S4Vectors_0.40.2
#  [37] ggrepel_0.9.6          irlba_2.3.5.1          listenv_0.9.1
#  [40] spatstat.utils_3.1-1   goftest_1.2-3          RSpectra_0.16-2
#  [43] spatstat.random_3.3-2  fitdistrplus_1.2-1     parallelly_1.39.0
#  [46] leiden_0.4.3.1         codetools_0.2-20       shape_1.4.6.1
#  [49] tidyselect_1.2.1       farver_2.1.2           matrixStats_1.4.1
#  [52] stats4_4.3.1           base64enc_0.1-3        spatstat.explore_3.3-3
#  [55] jsonlite_1.8.9         GetoptLong_1.0.5       progressr_0.15.0
#  [58] Formula_1.2-5          ggridges_0.5.6         survival_3.7-0
#  [61] iterators_1.0.14       foreach_1.5.2          tools_4.3.1
#  [64] ica_1.0-3              Rcpp_1.0.13-1          glue_1.8.0
#  [67] prodlim_2024.06.25     gridExtra_2.3          IRdisplay_1.1
#  [70] withr_3.0.2            fastmap_1.2.0          fansi_1.0.6
#  [73] digest_0.6.37          timechange_0.3.0       R6_2.5.1
#  [76] mime_0.12              colorspace_2.1-1       scattermore_1.2
#  [79] tensor_1.5             spatstat.data_3.1-2    utf8_1.2.4
#  [82] generics_0.1.3         data.table_1.16.2      recipes_1.1.0
#  [85] class_7.3-22           httr_1.4.7             htmlwidgets_1.6.4
#  [88] uwot_0.2.2             ModelMetrics_1.2.2.2   pkgconfig_2.0.3
#  [91] gtable_0.3.6           timeDate_4041.110      lmtest_0.9-40
#  [94] htmltools_0.5.8.1      carData_3.0-5          dotCall64_1.2
#  [97] clue_0.3-65            scales_1.3.0           png_0.1-8
# [100] gower_1.0.1            spatstat.univar_3.1-1  tzdb_0.4.0
# [103] reshape2_1.4.4         rjson_0.2.23           uuid_1.2-1
# [106] nlme_3.1-166           repr_1.1.7             zoo_1.8-12
# [109] GlobalOptions_0.1.2    KernSmooth_2.23-24     parallel_4.3.1
# [112] miniUI_0.1.1.1         pillar_1.9.0           vctrs_0.6.5
# [115] RANN_2.6.2             promises_1.3.0         car_3.1-3
# [118] xtable_1.8-4           cluster_2.1.6          evaluate_1.0.1
# [121] cli_3.6.3              compiler_4.3.1         rlang_1.1.4
# [124] crayon_1.5.3           future.apply_1.11.3    ggsignif_0.6.4
# [127] labeling_0.4.3         plyr_1.8.9             stringi_1.8.4
# [130] viridisLite_0.4.2      deldir_2.0-4           munsell_0.5.1
# [133] lazyeval_0.2.2         spatstat.geom_3.3-3    glmnet_4.1-8
# [136] Matrix_1.6-4           IRkernel_1.3.2         RcppHNSW_0.6.0
# [139] hms_1.1.3              patchwork_1.3.0        future_1.34.0
# [142] shiny_1.9.1            ROCR_1.0-11            igraph_2.1.1
# [145] broom_1.0.7
